# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("diabetes - diabetes (1).csv")
df
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
plt.figure(figsize=(9,3))
plt.scatter(df['Age'],df['BloodPressure'])
plt.xlabel("Age")
plt.ylabel("BloodPressure")
plt.show()

# %%
def bar_plot(variable):
    var=df[variable]
    varvalue=var.value_counts()
    plt.figure(figsize=(9,3))
    plt.bar(varvalue.index,varvalue)
    plt.xticks(varvalue.index,varvalue.index.values)
    plt.ylabel("frequency")
    plt.title(variable)
    plt.show()
    print("{}: \n {}".format(variable,varvalue))

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
columns_plot=['Glucose','BloodPressure','Insulin','BMI','Age']
for i in columns_plot:
    bar_plot(i)
# Out:
# Glucose:
#  Glucose
# 99     17
# 100    17
# 111    14
# 129    14
# 125    14
#        ..
# 191     1
# 177     1
# 44      1
# 62      1
# 190     1
# Name: count, Length: 136, dtype: int64
# BloodPressure:
#  BloodPressure
# 70     57
# 74     52
# 78     45
# 68     45
# 72     44
# 64     43
# 80     40
# 76     39
# 60     37
# 0      35
# 62     34
# 66     30
# 82     30
# 88     25
# 84     23
# 90     22
# 86     21
# 58     21
# 50     13
# 56     12
# 52     11
# 54     11
# 75      8
# 92      8
# 65      7
# 85      6
# 94      6
# 48      5
# 96      4
# 44      4
# 100     3
# 106     3
# 98      3
# 110     3
# 55      2
# 108     2
# 104     2
# 46      2
# 30      2
# 122     1
# 95      1
# 102     1
# 61      1
# 24      1
# 38      1
# 40      1
# 114     1
# Name: count, dtype: int64
# Insulin:
#  Insulin
# 0      374
# 105     11
# 130      9
# 140      9
# 120      8
#       ...
# 73       1
# 171      1
# 255      1
# 52       1
# 112      1
# ...

# %%
plt.hist(df['Age'])
plt.show()

# %%
def hist_plot(vari):
    var=df[vari]
    varValue=var.value_counts()
    plt.figure(figsize=(9,3))
    plt.bar(varValue.index,varValue)
    plt.xticks(varValue.index,varValue.index.values)
    plt.ylabel('Frequency')
    plt.title(vari)
    plt.show()
    print('{}:\n {}'.format(vari,varValue))

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
column_plot=['Glucose','Age','BMI']
for i in column_plot:
    h=hist_plot(i)
# Out:
# Glucose:
#  Glucose
# 99     17
# 100    17
# 111    14
# 129    14
# 125    14
#        ..
# 191     1
# 177     1
# 44      1
# 62      1
# 190     1
# Name: count, Length: 136, dtype: int64
# Age:
#  Age
# 22    72
# 21    63
# 25    48
# 24    46
# 23    38
# 28    35
# 26    33
# 27    32
# 29    29
# 31    24
# 41    22
# 30    21
# 37    19
# 42    18
# 33    17
# 38    16
# 36    16
# 32    16
# 45    15
# 34    14
# 46    13
# 43    13
# 40    13
# 39    12
# 35    10
# 50     8
# 51     8
# 52     8
# 44     8
# 58     7
# 47     6
# 54     6
# 49     5
# 48     5
# 57     5
# 53     5
# 60     5
# 66     4
# 63     4
# 62     4
# 55     4
# 67     3
# 56     3
# 59     3
# 65     3
# 69     2
# 61     2
# 72     1
# 81     1
# 64     1
# 70     1
# 68     1
# Name: count, dtype: int64
# BMI:
#  BMI
# 32.0    13
# 31.6    12
# 31.2    12
# 0.0     11
# 32.4    10
#         ..
# 36.7     1
# 41.8     1
# 42.6     1
# 42.8     1
# 46.3     1
# ...

# %%
df[['Glucose','Age']].groupby(['Glucose'],as_index=False).mean().sort_values(by='Age',ascending=False)
# Out:
#      Glucose        Age
# 127      190  66.000000
# 130      194  55.666667
# 114      176  55.000000
# 3         57  54.000000
# 99       161  53.000000
# ..       ...        ...
# 51       113  22.400000
# 17        79  22.333333
# 2         56  22.000000
# 135      199  22.000000
# 115      177  21.000000
#
# [136 rows x 2 columns]

# %%
df[['Insulin','BMI']].groupby(['Insulin'],as_index=False).mean().sort_values(by='BMI',ascending=False)
# Out:
#      Insulin    BMI
# 1         14  59.40
# 183      680  52.30
# 133      240  51.35
# 137      255  47.90
# 126      220  47.65
# ..       ...    ...
# 12        38  19.60
# 158      326  19.60
# 14        41  19.50
# 19        46  19.50
# 58        89   0.00
#
# [186 rows x 2 columns]

# %%
df[['Pregnancies','BloodPressure']].groupby(['Pregnancies'],as_index=False).mean().sort_values(by='BloodPressure',ascending=False)
# Out:
#     Pregnancies  BloodPressure
# 9             9      77.892857
# 12           12      76.333333
# 5             5      76.210526
# 8             8      75.184211
# 11           11      74.181818
# 13           13      73.800000
# 16           17      72.000000
# 7             7      70.777778
# 10           10      70.208333
# 4             4      70.029412
# 14           14      70.000000
# 15           15      70.000000
# 6             6      68.420000
# 1             1      67.792593
# 0             0      67.153153
# 3             3      66.586667
# 2             2      63.252427

# %%
def box_plot(vari, df):
    plt.figure(figsize=(9, 4))
    sns.boxplot(y=df[vari])
    plt.title(f'Box Plot of {vari}')
    plt.ylabel(vari)
    plt.show()

# %%
colum_plot=['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']
for i in colum_plot:
    if df[i].dtype in ['int64', 'float64']:  
        box_plot(i, df)

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
df['BloodPressure']=df['BloodPressure'].fillna(df['BloodPressure'].median())
df['Age']=df['Age'].fillna(df['Age'].median())
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df['Insulin'].mode()
# Out:
# 0    0
# Name: Insulin, dtype: int64

# %%
df['Insulin']=df['Insulin'].fillna(df['Insulin'].mode()[0])

# %%
df.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.drop(labels=['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI'],axis=1)
# Out:
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.drop(labels=['BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin
# 0            6      148             72             35        0
# 1            1       85             66             29        0
# 2            8      183             64              0        0
# 3            1       89             66             23       94
# 4            0      137             40             35      168

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Pregnancies    768 non-null    int64
#  1   Glucose        768 non-null    int64
#  2   BloodPressure  768 non-null    int64
#  3   SkinThickness  768 non-null    int64
#  4   Insulin        768 non-null    int64
# dtypes: int64(5)
# memory usage: 30.1 KB

# %%
df['Insulin'] = df['Insulin'].astype('category').cat.codes

# %%
df.head()
# Out:
#    Pregnancies  Glucose  SkinThickness  Insulin  BloodPressure_24  \
# 0            6      148             35        0             False
# 1            1       85             29        0             False
# 2            8      183              0        0             False
# 3            1       89             23       62             False
# 4            0      137             35      102             False
#
#    BloodPressure_30  BloodPressure_38  BloodPressure_40  BloodPressure_44  \
# 0             False             False             False             False
# 1             False             False             False             False
# 2             False             False             False             False
# 3             False             False             False             False
# 4             False             False              True             False
#
#    BloodPressure_46  ...  BloodPressure_96  BloodPressure_98  \
# ...

# %%
sns.heatmap(df.corr(),annot=True,fmt='.2f')
plt.show()
